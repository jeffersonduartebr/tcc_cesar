# %%
import pandas as pd
import requests
import json
import datetime, dateutil
import concurrent.futures
import swifter
import os
import mariadb
import sys

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
def conectar_banco():    
    try:
        conn = mariadb.connect(
            user="root",
            password="abc@123",
            host="172.17.0.3",
            port=3306,
            database='dados_tribunais',
            autocommit=True
        )
        print("Connection established successfully!")
    except mariadb.Error as e:
        print(f"Error connecting to MariaDB: {e}")
        
    # Get Cursor
    cursor = conn.cursor()
    return cursor

#     processos.append([numero_processo, classe, data_ajuizamento, ultima_atualizacao, \
#                      codigo, orgao_julgador, municipio, grau, assuntos, movimentos, sort])

def criar_bd(nome):
    cursor = conectar_banco()
    cursor.execute("CREATE DATABASE IF NOT EXISTS dados_tribunais")
    #cursor.commit()
    cursor.close()
    
def criar_tabela():
    try:
        cursor = conectar_banco()

        cursor.execute('''
            CREATE TABLE IF NOT EXISTS processos (
                numero_processo VARCHAR(255) PRIMARY KEY,
                tribunal VARCHAR(255),
                classe VARCHAR(255),
                data_ajuizamento DATE,
                ultima_atualizacao DATE,
                codigo VARCHAR(50),
                orgao_julgador VARCHAR(255),
                municipio VARCHAR(255),
                grau VARCHAR(50),
                assuntos TEXT,
                movimentos TEXT
            )
        ''')

        print("Tabela 'tribunal_data' criada com sucesso!")

    except: 
        print(f"Erro na criação da tabela")
    cursor.close()

            
def adicionar_processo_mariadb(cursor, numero_processo, tribunal, classe, data_ajuizamento, ultima_atualizacao, codigo, orgao_julgador, municipio, grau, assuntos, movimentos):
    try:
        cursor.execute('''
            INSERT INTO processos (numero_processo, tribunal, classe, data_ajuizamento, ultima_atualizacao, codigo, orgao_julgador, municipio, grau, assuntos, movimentos)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ''', (numero_processo, tribunal, classe, data_ajuizamento, ultima_atualizacao, codigo, orgao_julgador, municipio, grau, assuntos, movimentos))
        
        
    except mariadb.Error as e:
        print(f"Error adding entry to database: {e}")

# %%
def converte_data(data_str):
    data = dateutil.parser.parse(data_str)
    data = datetime.datetime.date(data)
    return data.strftime('%Y-%m-%d')


def gera_lista_assuntos(assuntos_do_df):
    lst_assuntos=[]
    for assunto in assuntos_do_df:
        try:
            lst_assuntos.append(assunto.get('nome'))
        except:
            lst_assuntos.append('')

    return lst_assuntos


def gera_lista_movimentos(movimentos):
    lst_movimentos_final =[]
    for movimento in movimentos:
        codigo = movimento.get('codigo')
        nome = movimento.get('nome')
        data_hora = movimento.get('dataHora')
        if data_hora:
            data_hora = converte_data(data_hora)
        lst_movimentos_final.append([ codigo, nome, data_hora])
    return lst_movimentos_final

def process_movimento(movimento):
    codigo = movimento.get('codigo')
    nome = movimento.get('nome')
    data_hora = movimento.get('dataHora')
    if data_hora:
        data_hora = converte_data(data_hora)
    return [codigo, nome, data_hora]

def gera_lista_movimentos_multithread(movimentos):
    lst_movimentos_final = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(process_movimento, movimentos))
        lst_movimentos_final.extend(results)
    return lst_movimentos_final

# %%
def obter_data(item):
    return datetime.strptime(item[2], '%Y-%m-%d')
  
def lista_para_dataframe(conector, dados_dict):
  processos = []
  for processo in dados_dict['hits']['hits']:
    numero_processo = processo['_source']['numeroProcesso']
    grau = processo['_source']['grau']
    tribunal = processo['_source']['tribunal']
    classe = processo['_source']['classe']['nome']
    try:
      assuntos = processo['_source']['assuntos'] # Pode ter mais de um
      asuntos = gera_lista_assuntos(assuntos)
    except:
      assuntos = []
    data_ajuizamento = converte_data(processo['_source']['dataAjuizamento'])
    ultima_atualizacao = converte_data(processo['_source']['dataHoraUltimaAtualizacao'])
    #formato = processo['_source']['formato']['nome']
    codigo = processo['_source']['orgaoJulgador']['codigo']
    orgao_julgador = processo['_source']['orgaoJulgador']['nome']
    municipio = processo['_source']['orgaoJulgador']['codigoMunicipioIBGE']
    sort = processo['sort'][0]
    try:
      movimentos = processo['_source']['movimentos']
      movimentos = gera_lista_movimentos_multithread(movimentos)
     
      movimentos = sorted(movimentos, key=lambda x: x[2])
      #print(movimentos)     
    except:
      movimentos = []
    assuntos_str = '; '.join(str(assunto) for assunto in assuntos)
    movimentos_str = '; '.join(str(movimento) for movimento in movimentos)
    adicionar_processo_mariadb( conector, numero_processo, tribunal, classe,
                               data_ajuizamento, ultima_atualizacao, codigo,
                               orgao_julgador, municipio, grau, assuntos_str,
                               movimentos_str)

# %%
def criar_dataset(conector, codigo_orgao, data, tamanho_consulta):
  
  df_tribunal = pd.DataFrame()
  url = "https://api-publica.datajud.cnj.jus.br/api_publica_tjrn/_search"
  api_key = "APIKey cDZHYzlZa0JadVREZDJCendQbXY6SkJlTzNjLV9TRENyQk1RdnFKZGRQdw==" # Chave pública
  tribunal = 'TJRN'
  orgaoJulgador = codigo_orgao
  size = tamanho_consulta
  data = data

  payload = json.dumps(
  {
  "size": tamanho_consulta,
  "query": {
      "bool": {
        "must": [
            {"match": {"tribunal": tribunal}},
            {"match": {"orgaoJulgador.codigo": orgaoJulgador}},
            {"range": {"dataAjuizamento": {"gte": data }}}
        ]
      }
  },
    "sort": [{"@timestamp": {"order": "asc"}}]
  })

  headers = {
    'Authorization': api_key,
    'Content-Type': 'application/json'
  }

  response = requests.request("POST", url, headers=headers, data=payload)  # <Response [200]>
  dados_dict = response.json() # <class 'dict'>
  if len(dados_dict['hits']['hits']) < 5:
    print(f'Parece que você digitou um código de Serventia errado. Confira novamente.')
  lista_para_dataframe(conector, dados_dict)
  numero_processos = size

  while numero_processos == size:
    numero_processos = len(dados_dict['hits']['hits'])
    tamanho_dicionario_retornado = len(dados_dict['hits']['hits'])-1
    if tamanho_dicionario_retornado < 1:
      print(f'Tamanho do dicionário da página anterior: {tamanho_dicionario_retornado}')
      continue
    ultima_posicao_dicionario = dados_dict['hits']['hits'][(len(dados_dict['hits']['hits'])-1)]['sort'][0]
    #print(f'Partindo da posição: {ultima_posicao_dicionario}')
    payload = json.dumps(
    {
    "size": tamanho_consulta,
    "query": {
        "bool": {
          "must": [
            {"match": {"tribunal": tribunal}},
            {"match": {"orgaoJulgador.codigo": orgaoJulgador}},
            {"range": {"dataAjuizamento": {"gte": data}}}
            
          ]
        }
    },
      "search_after": [ ultima_posicao_dicionario ],
      "sort": [{"@timestamp": {"order": "asc"}}]
    })

    headers = {
      'Authorization': api_key,
      'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)  # <Response [200]>
    dados_dict = response.json() # <class 'dict'>
    numero_processos = len(dados_dict['hits']['hits'])
    ultima_posicao_dicionario = dados_dict['hits']['hits'][(len(dados_dict['hits']['hits'])-1)]['sort']
    lista_para_dataframe(conector, dados_dict)
    ultima_data_ajuizamento = dados_dict['hits']['hits'][len(dados_dict['hits']['hits'])-1]['_source']['dataAjuizamento']
    orgao_julgador = dados_dict['hits']['hits'][len(dados_dict['hits']['hits'])-1]['_source']['orgaoJulgador']['nome']
    print(f'{datetime.datetime.now()}\t Serventia: {orgao_julgador}\t Data do último processo adicionado: {ultima_data_ajuizamento}' )
    #if tamanho_dataset > 2000000:
    #  break

  return

# %%
def salvar_dataset(df, orgao, data):        
    if not type(orgao) is str:
        str(orgao)
    orgao = orgao.replace(' ', '_')
    nome_df = 'TJRN_' + orgao + '_' + data + '.csv'
    nome_df = nome_df.replace(" ", "_")
    if os.path.isdir('./dados'):
        os.chdir('dados')
    df.to_csv(nome_df, sep=';', header=True, index=False)

# %%
lista_codigo_orgaos = [75496, 17460, 17461 ] # 4º, 2º e 1º JEFP
data = '2018-01-01'
criar_bd('dados_tribunais')
criar_tabela()
cursor = conectar_banco()
for orgao in lista_codigo_orgaos:
    criar_dataset(cursor, orgao, data, 10000)

cursor.close()
# Out:
# Connection established successfully!
# Connection established successfully!
# Tabela 'tribunal_data' criada com sucesso!
# Connection established successfully!
# Error adding entry to database: Duplicate entry '08281768720228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08071280420248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08051921220228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08457789620198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08725191320188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08141444820208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08070528720188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08605996620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08628531720208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08380376320238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08674736720238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08659364120208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08230237320228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08173212020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '09212422420228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08156067420198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08736521720238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08150409120208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08145948820208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08757368820238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08480454120198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08252307920218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08328054120218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08054708120208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08300886120188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08592498220198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08637556220238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08389423920218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08660706320238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08587072520238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08181750920238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08234423020218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08586972020198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08009191920248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08660118020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08476565620198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08542741720198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08544372620218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08273425520208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08157698820188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08043149220198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08498791120218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08548238520238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08114592920248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08779704820208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08645169820208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08753624820188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08178434220238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '09063207520228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08087193520238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08740307520208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08161372420238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08108274220208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08606386320238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08496236820218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08290284320248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08288970520238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08271419220228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08611992420228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08117677020218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08333804920218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08193832820238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08556471520218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08542253420238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08711602820188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08998494320228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08268477420218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '09149225520228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08584587420238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08068767420198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08589908220228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08001805120218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '09152403820228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08699367920238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08066787120188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08185735820208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08315372020198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08226288120228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08030110420238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08092072920198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08699150620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08172423620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08601715520218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08028878920218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08098268520218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08025061820208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08125641720198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08591775620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08595416720198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08869842720188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08610774520218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08553960220188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08283572020248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08167094320248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '09084244020228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08143826720208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08130376120238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08824633920188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08232965720198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08626326320228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08697514620208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08066841020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08113770820188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08084189320208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08112151320188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08688472620208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08329705920198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08532314520198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08153113720198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08224475120208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08758087520238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08407259520238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08044023320198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08294424620218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08216740620208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08497922620198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08737301120238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08290261020238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08327679220228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08202164620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08708329820188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '09196426520228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08226085620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08333591020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08265457420238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08324044720188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08579507020198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08558535820238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08097838020238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08037112920188205106' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08667089620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08390520420228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08726268120238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08498381520198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08214428620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08046003620208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08196454120248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08000635520248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08159554320208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '09152412320228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08017039820218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08275827320228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08196760320208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08090886320228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08069626920248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08223037720208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08717615820238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08555802120198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08651023320238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08107632720238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08719321520238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08245234320238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08220101020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08134700220228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08469377420198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08679716620238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08755255220238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08338244820228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08001779620218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08120950520188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08802229220188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08005372620248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08517747520198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08265514720248205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08754631220238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08737143320188205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08295362820208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08054421120238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08541803020238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08028604320208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08124853820198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08327878820198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08154444520208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08394926320238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08635556020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08497487020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08110128020208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08559474520198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08724451720228205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08512654720198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08354429120238205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08171604420198205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08287179120208205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '08495673520218205001' for key 'PRIMARY'
# Error adding entry to database: Duplicate entry '