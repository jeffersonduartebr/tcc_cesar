# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask
import dask.dataframe as dd
from dask.distributed import Client

# %%
client = Client(n_workers=4, memory_limit='8GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:41675' processes=4 threads=8, memory=22.35 GiB>

# %%
#df = pd.read_csv('dados/TRF4_JE_2018-01-01.csv', header='infer', sep=';', compression='zip')
#df.to_parquet('dados/TRF4_JE_2018-01-01.parquet', index=False, compression='gzip')
#df = None
dd = dd.read_csv('dados/TRF4_JE_2018-01-01.csv', delimiter=';', compression='zip', blocksize=None)
dd = dd.drop(columns=['sort', 'tribunal', 'ultima_atualizacao'])
dd.repartition(partition_size="100MB")
# Out:
# 2024-06-03 13:20:48,102 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:36035 (pid=49458) exceeded 95% memory budget. Restarting...
# 2024-06-03 13:20:48,224 - distributed.nanny - WARNING - Restarting worker
# Task exception was never retrieved
# future: <Task finished name='Task-373' coro=<Client._gather.<locals>.wait() done, defined at /dados/tcc_cesar/.venv/lib/python3.11/site-packages/distributed/client.py:2199> exception=AllExit()>
# Traceback (most recent call last):
#   File "/dados/tcc_cesar/.venv/lib/python3.11/site-packages/distributed/client.py", line 2208, in wait
#     raise AllExit()
# distributed.client.AllExit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 dd = dd.read_csv('dados/TRF4_JE_2018-01-01.csv', delimiter=';', compression='zip', blocksize=None)
#       5 dd = dd.drop(columns=['sort', 'tribunal', 'ultima_atualizacao'])
# ----> 6 dd.repartition(partition_size="100MB")
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:711, in PlainTextFormatter.__call__(self, obj)
#     704 stream = StringIO()
#     705 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     706     self.max_width, self.newline,
#     707     max_seq_length=self.max_seq_length,
#     708     singleton_pprinters=self.singleton_printers,
#     709     type_pprinters=self.type_printers,
#     710     deferred_pprinters=self.deferred_printers)
# --> 711 printer.pretty(obj)
#     712 printer.flush()
#     713 return stream.getvalue()
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/IPython/lib/pretty.py:411, in RepresentationPrinter.pretty(self, obj)
#     408                         return meth(obj, self, cycle)
#     409                 if cls is not object \
#     410                         and callable(cls.__dict__.get('__repr__')):
# --> 411                     return _repr_pprint(obj, self, cycle)
#     413     return _default_pprint(obj, self, cycle)
#     414 finally:
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/IPython/lib/pretty.py:779, in _repr_pprint(obj, p, cycle)
#     777 """A pprint that just redirects to the normal repr function."""
#     778 # Find newlines and replace them with p.break_()
# --> 779 output = repr(obj)
#     780 lines = output.splitlines()
#     781 with p.group():
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_collection.py:418, in FrameBase.__repr__(self)
#     417     def __repr__(self):
# --> 418         data = self._repr_data().to_string(max_rows=5)
#     419         _str_fmt = """Dask {klass} Structure:
#     420 {data}
#     421 Dask Name: {name}, {n_expr}
#     422 Expr={expr}"""
#     423         if not isinstance(self, Series) and not len(self.columns):
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_collection.py:4017, in DataFrame._repr_data(self)
#    4015 def _repr_data(self):
#    4016     meta = self._meta
# -> 4017     index = self._repr_divisions
#    4018     cols = meta.columns
#    4019     if len(cols) == 0:
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_collection.py:2573, in FrameBase._repr_divisions(self)
#    2571 @property
#    2572 def _repr_divisions(self):
# -> 2573     name = f"npartitions={self.npartitions}"
#    2574     if self.known_divisions:
#    2575         divisions = pd.Index(self.divisions, name=name)
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_collection.py:345, in FrameBase.npartitions(self)
#     342 @property
#     343 def npartitions(self):
#     344     """Return number of partitions"""
# --> 345     return self.expr.npartitions
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_repartition.py:63, in Repartition.npartitions(self)
#      61         return new_partitions(self.frame.npartitions)
#      62     return new_partitions
# ---> 63 return super().npartitions
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_expr.py:398, in Expr.npartitions(self)
#     396     return self.operands[idx]
#     397 else:
# --> 398     return len(self.divisions) - 1
#
# File /usr/lib/python3.11/functools.py:1001, in cached_property.__get__(self, instance, owner)
#     999 val = cache.get(self.attrname, _NOT_FOUND)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#    1003         cache[self.attrname] = val
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_expr.py:382, in Expr.divisions(self)
#     380 @functools.cached_property
#     381 def divisions(self):
# --> 382     return tuple(self._divisions())
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_repartition.py:50, in Repartition._divisions(self)
#      45 if (
#      46     self.operand("new_partitions") is not None
#      47     or self.partition_size is not None
#      48 ):
#      49     x = self.optimize(fuse=False)
# ---> 50     return x._divisions()
#      51 return self.new_divisions
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_repartition.py:436, in RepartitionSize._divisions(self)
#     435 def _divisions(self):
# --> 436     if np.any(self._nsplits > 1):
#     437         return (None,) * len(self._partition_boundaries)
#     438     return (self.frame.divisions[i] for i in self._partition_boundaries)
#
# File /usr/lib/python3.11/functools.py:1001, in cached_property.__get__(self, instance, owner)
#     999 val = cache.get(self.attrname, _NOT_FOUND)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#    1003         cache[self.attrname] = val
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_repartition.py:415, in RepartitionSize._nsplits(self)
#     413 @functools.cached_property
#     414 def _nsplits(self):
# --> 415     return 1 + _get_mem_usages(self.frame) // self._size
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_repartition.py:490, in _get_mem_usages(frame)
#     488 if frame._name in mem_usages_lru:
#     489     return mem_usages_lru[frame._name]
# --> 490 result = _compute_mem_usages(frame)
#     491 mem_usages_lru[frame._name] = result
#     492 return result
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_repartition.py:498, in _compute_mem_usages(frame)
#     495 def _compute_mem_usages(frame):
#     496     from dask_expr._collection import new_collection
# --> 498     return new_collection(TotalMemoryUsageFrame(frame, deep=True)).compute()
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask_expr/_collection.py:476, in FrameBase.compute(self, fuse, **kwargs)
#     474     out = out.repartition(npartitions=1)
#     475 out = out.optimize(fuse=fuse)
# --> 476 return DaskMethodsMixin.compute(out, **kwargs)
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask/base.py:375, in DaskMethodsMixin.compute(self, **kwargs)
#     351 def compute(self, **kwargs):
#     352     """Compute this dask collection
#     353
#     354     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     373     dask.compute
#     374     """
# --> 375     (result,) = compute(self, traverse=False, **kwargs)
#     376     return result
#
# File /dados/tcc_cesar/.venv/lib/python3.11/site-packages/dask/base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658     postcomputes.append(x.__dask_postcompute__())
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /usr/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /usr/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
print(dd.columns)

# %%
print(dd.info())

# %%
print(dd.describe())

# %%
print(dd.shape)

# %%
print(dd['movimentos'].head(20))

# %%
client.close()
